# %% [markdown]
# # Exploratory Data Analysis- Retail (TSF~ GRIP)
# By:  Priynka Sorate

# %%
#Importing diverse libraries to perform certain task on the given data set
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt

# %%
#Reading the .csv file named SampleSuperstore
d1=pd.read_csv("/content/SampleSuperstore.csv")

#Displaying the dataset named SampleSuperstore.csv using pandas library
d1.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Checking colums and row i the data set
d1.shape
# Out:
# (9994, 13)

# %% [markdown]
# In our dataset there is 9994 coiums and 13 rows.

# %%
#Check datatype of each attribute
d1.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#Obtain a concise summary of a DataFrame
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#check the distict values
d1.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Check missing values
d1.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Upo checking the dataset, we can see that there is no missing values.

# %%
#Checking statistical summary of a dataset.
d1.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Checkig data where the profit is negative and sorting it by Profit.
d2=round(d1[d1['Profit']<0].sort_values(by='Profit',ascending=True),2)
d2
# Out:
#            Ship Mode      Segment        Country          City  \
# 7772  Standard Class     Consumer  United States     Lancaster
# 683         Same Day    Corporate  United States    Burlington
# 9774  Standard Class     Consumer  United States   San Antonio
# 3011  Standard Class  Home Office  United States    Louisville
# 4991  Standard Class    Corporate  United States       Chicago
# ...              ...          ...            ...           ...
# 4660  Standard Class     Consumer  United States  Philadelphia
# 7413  Standard Class  Home Office  United States        Tigard
# 1566     First Class     Consumer  United States         Allen
# 1496  Standard Class     Consumer  United States       Coppell
# 3228     First Class    Corporate  United States         Tempe
#
#                State  Postal Code   Region         Category Sub-Category  \
# 7772            Ohio        43130     East       Technology     Machines
# ...

# %%
# Checking when the profit is largest and smallest in negative
d2[['Ship Mode','Sales','Profit']][(d2['Profit']==-6599.98) | (d2['Profit']==-0.09)]
# Out:
#            Ship Mode    Sales   Profit
# 7772  Standard Class  4499.98 -6599.98
# 3228     First Class     7.16    -0.09

# %% [markdown]
# Profit lies between -6599 to -0.09

# %%
#percentage when Ship Mode is Standard Class
f=len(d2[d2['Ship Mode']=='Standard Class'].value_counts().reset_index())
round((f/1871)*100,2)
# Out:
# 62.64

# %%
#percentage when Ship Mode is First Class
f=len(d2[d2['Ship Mode']=='First Class'].value_counts().reset_index())
round((f/1871)*100,2)
# Out:
# 15.66

# %%
#percentage when Ship Mode is Second Class
f=len(d2[d2['Ship Mode']=='Second Class'].value_counts().reset_index())
round((f/1871)*100,2)
# Out:
# 16.35

# %%
#percentage when Ship Mode is Same Day
f=len(d2[d2['Ship Mode']=='Same Day'].value_counts().reset_index())
round((f/1871)*100,2)
# Out:
# 5.24

# %%
l1=['Standard Class','Second Class','First Class','Same Day']
l2=[62.64,16.35,15.66,5.24]

# %%
#Percentage of Ship Mode used
plt.figure(figsize=(14,6))
plt.pie(l2,labels=l1,colors=['Pink','Orange','Red','Yellow'],autopct='%0.1f%%')
plt.show()

# %% [markdown]
# • Percentages for different Ship Modes:
# a) Standard Class~ 62.7%
# b) Second Class~ 16.4%
# c) First Class~ 15.7%
# d) Same Day~ 5.2%

# %%
#taking top 20 values sorted by sales
b1=d2.nlargest(20,columns='Sales')
b1
# Out:
#            Ship Mode      Segment        Country           City  \
# 2697  Standard Class  Home Office  United States   Jacksonville
# 165   Standard Class     Consumer  United States    San Antonio
# 683         Same Day    Corporate  United States     Burlington
# 1803    Second Class     Consumer  United States   Philadelphia
# 7772  Standard Class     Consumer  United States      Lancaster
# 7243    Second Class     Consumer  United States   Philadelphia
# 9639    Second Class     Consumer  United States        Concord
# 6535  Standard Class     Consumer  United States        Buffalo
# 5198  Standard Class     Consumer  United States     Round Rock
# 27    Standard Class     Consumer  United States   Philadelphia
# 262     Second Class    Corporate  United States        Houston
# 4128  Standard Class     Consumer  United States      Charlotte
# 3011  Standard Class  Home Office  United States     Louisville
# 263     Second Class    Corporate  United States        Houston
# ...

# %%
#counting total count of Standard Class in top 20 values
b1['Ship Mode'].value_counts()
# Out:
# Standard Class    11
# Second Class       6
# Same Day           2
# First Class        1
# Name: Ship Mode, dtype: int64

# %%
#graph showing ship modes and their count
plt.figure(figsize=(8,5))
plt.bar(b1['Ship Mode'].value_counts().keys(),b1['Ship Mode'].value_counts(),color='Brown')
plt.show()

# %% [markdown]
# Heavy discount between 20% to 80% when the Ship Mode is
# “Standard Class” for top 20 values.

# %%
#Bar Graph for top 20 values showing different Ship Modes, sorted by Sales
plt.figure(figsize=(6,5))
plt.xlabel('Ship Modes',labelpad=10)
plt.ylabel('Sales',labelpad=10)
plt.bar(b1['Ship Mode'],b1['Sales'],color='Pink')
plt.show()

# %% [markdown]
# Maximum sales is of 22638.48 when the Ship Mode is Standard
# Class, in overall dataset.

# %% [markdown]
# Minimum sales is of 2003.92 for Standard Class in top 20
# values and Minimum sales is of 0.44 for Standard Class in overall records

# %%
#analysing top 20 records where the Ship Mode is Standard Class
b1[['Profit','Ship Mode','Discount','Sales']][b1['Ship Mode']=='Standard Class'].reset_index()
# Out:
#     index   Profit       Ship Mode  Discount     Sales
# 0    2697 -1811.08  Standard Class       0.5  22638.48
# 1     165 -1359.99  Standard Class       0.4   8159.95
# 2    7772 -6599.98  Standard Class       0.7   4499.98
# 3    6535   -50.10  Standard Class       0.2   4007.84
# 4    5198  -786.01  Standard Class       0.2   3930.07
# 5      27 -1665.05  Standard Class       0.5   3083.43
# 6    4128  -944.99  Standard Class       0.5   2624.98
# 7    3011 -3399.98  Standard Class       0.7   2549.98
# 8    9774 -3701.89  Standard Class       0.8   2177.58
# 9     949  -619.60  Standard Class       0.4   2065.32
# 10   5918   -25.05  Standard Class       0.2   2003.92

# %%
#Graph showing Negative Profit(loss) for different Ship Modes
plt.bar(b1['Ship Mode'],b1['Profit'],color='Orange')
plt.show()

# %%
#plot between Dicount and Ship Mode for top 20 values
b2=b1['Ship Mode'][b1['Ship Mode']=='Standard Class']
b1.plot(kind='bar',x='Ship Mode',y='Discount',figsize=(14,6),color='brown')
plt.xlabel('Ship Mode',labelpad=20)
plt.ylabel('Discount',labelpad=20)
plt.show()

# %% [markdown]
# Heavy discount between 20% to 80% when the Ship Mode is
# “Standard Class” for top 20 values

# %%
#maximum loss when the ship mode is Standard Class in 9994 records
round(d1[(d1['Profit']==d1['Profit'].min()) & (d1['Ship Mode']=='Standard Class')],2)
# Out:
#            Ship Mode   Segment        Country       City State  Postal Code  \
# 7772  Standard Class  Consumer  United States  Lancaster  Ohio        43130
#
#      Region    Category Sub-Category    Sales  Quantity  Discount   Profit
# 7772   East  Technology     Machines  4499.98         5       0.7 -6599.98

# %% [markdown]
# Maximum loss is of -6599 for Standard Class while looking at
# overall data with 70% discount

# %%
#maximum Sales when the ship mode is Standard Class in 9994 records
round(d1[(d1['Ship Mode']=='Standard Class') & (d1['Sales']==d1['Sales'].max())],2)
# Out:
#            Ship Mode      Segment        Country          City    State  \
# 2697  Standard Class  Home Office  United States  Jacksonville  Florida
#
#       Postal Code Region    Category Sub-Category     Sales  Quantity  \
# 2697        32216  South  Technology     Machines  22638.48         6
#
#       Discount   Profit
# 2697       0.5 -1811.08

# %% [markdown]
# Maximum Sales is of -1811.08 for Standard Class while looking at
# overall data with 50% discount.

# %%
#minimum Sales when the ship mode is Standard Class in top 20 values
b1[(b1['Sales']==b1['Sales'].min()) & (b1['Ship Mode']=='Standard Class')]
# Out:
#            Ship Mode   Segment        Country           City     State  \
# 5918  Standard Class  Consumer  United States  New York City  New York
#
#       Postal Code Region   Category Sub-Category    Sales  Quantity  Discount  \
# 5918        10035   East  Furniture    Bookcases  2003.92         5       0.2
#
#       Profit
# 5918  -25.05

# %% [markdown]
# • Minimum loss is of -25.05 for Standard Class while analysing
# top 20 records with 20% discount

# %%
#minimum Sales when the ship mode is Standard Class in 9994 records
round(d1[(d1['Ship Mode']=='Standard Class') & (d1['Sales']==d1['Sales'].min())],2)
# Out:
#            Ship Mode   Segment        Country     City  State  Postal Code  \
# 4101  Standard Class  Consumer  United States  Houston  Texas        77095
#
#        Region         Category Sub-Category  Sales  Quantity  Discount  Profit
# 4101  Central  Office Supplies   Appliances   0.44         1       0.8   -1.11

# %% [markdown]
# # Conclusion:Discount needs to be reduced below 20% for “Standard Class”
# # **so that profit can be maximized.**
